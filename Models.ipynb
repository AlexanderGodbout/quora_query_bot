# %%
from ques_db import ques_db

db = ques_db()
db.cursor.execute('SELECT * FROM benchmarks')
benchmarks = db.cursor.fetchall()


from sklearn.linear_model import ElasticNet



from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

kw_list = ["Blockchain", "Bitcoin"]
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')

pytrends.interest_over_time()

# topicality, sentiment, word_count = (earning, views, etc...) 
# topicality = highest topic score
# sentiment = sensationalism rank
# word_count 

import nltk

print(benchmarks)

# views +... earnings
# Out:
# [{'id': 1, 'earnings': Decimal('0.00'), 'question': 'How do you think Leia Organas story should conclude?', 'ask_date': datetime.date(2020, 10, 18), 'topics': '[[Leia Organa (Star Wars character), Star Wars Movies]]', 'answer_count': 0, 'request_count': 25, 'followers': 1, 'views': 21, 'ad_impressions': 0, 'traffic_sources': 'Needs more views', 'question_earnings': Decimal('0.00'), 'request_earnings': Decimal('0.00'), 'version': '0.0.0.0', 'timestamp': datetime.datetime(2020, 11, 2, 8, 1, 38)}, {'id': 2, 'earnings': Decimal('0.00'), 'question': 'How should I send my first message to someone I am interested in?', 'ask_date': datetime.date(2020, 10, 18), 'topics': '[[Messaging, Text Messaging, Interpersonal Interaction]]', 'answer_count': 3, 'request_count': 25, 'followers': 1, 'views': 871, 'ad_impressions': 17, 'traffic_sources': '81% Internal\n19% External', 'question_earnings': Decimal('0.00'), 'request_earnings': Decimal('0.00'), 'version': '0.0.0.0', 'timestamp': datetime.datetim
# ...

# %%
months = range(0,12*30)


rent_net_worth = 0 
home_net_worth = 0

home_rate_of_return = 0.03/12
stock_rate_of_return = 0.07/12

AirBnb_Revenue = 3000

for month in months:
    home_net_worth += home_net_worth * home_rate_of_return + 5000 - 800 + 4000
    rent_net_worth += rent_net_worth * stock_rate_of_return + 5000 - 1500
    
print(home_net_worth)
print(rent_net_worth)
# Out:
# 4778442.453705986
# 4269898.485215763

# %%
earnings_per_sentence = 0.07 
sentences_posted_per_day = 500
earnings_per_month = earnings_per_sentence * sentences_posted_per_day*30

print(earnings_per_month)
# Out:
# 1050.0
